# %% [markdown]
# **Description:**
#
# Using the 'textblob' library to perform NLP analysis on multiple stocks. The objective is to rank stocks based on average sentiment values.

# %%
# !pip install pyfinviz
# !pip install textblob

# %%
from textblob import TextBlob
import numpy as np
from pyfinviz.quote import Quote
import pandas as pd
import yfinance as yf

# %%
universe = ['SPY', 'V', 'PYPL', 'VZ', 'T', 'VIV', 'AMX', 'VOD', 'TU', 'TEF', 'TSLA', 
           'GM', 'F', 'STLA', 'HMC', 'NIO', 'PG', 'KO', 'PEP', 'ABEV', 'NKE',
           'PM', 'UL', 'BUD', 'MDLZ', 'MO', 'DIS', 'CMCSA', 'SBUX', 'WBD',
           'BSX', 'HLN', 'AAPL', 'NVDA', 'TSM', 'CSCO', 'QCOM', 'RTX', 'AMD',
           'INTC', 'MU', 'NOK', 'XOM', 'PBR', 'CVX', 'SHEL', 'COP', 'TTE', 'BP', 
           'EQNR', 'CNQ', 'SU', 'UBS', 'JPM', 'BAC', 'ITUB', 'WFC', 
           'MS', 'HSBC', 'SCHW', 'BBD', 'JNJ', 'MRK', 'ABBV', 'PFE', 'NVO', 
           'NVS', 'AZN', 'ABT', 'BMY', 'SNY', 'ENB', 'SLB', 'EPD', 'KMI', 'ET', 
           'VALE', 'BHP', 'RIO', 'FCX', 'GOLD', 'SUZ', 'AMCR', 'GE', 'ABB', 
           'AMZN', 'WMT', 'HD', 'BABA', 'PDD', 'CVS', 'JD', 'TJX', 'CPNG', 
           'MSFT', 'GOOG', 'GOOGL', 'META', 'ORCL', 'BEKE', 'SAP', 'INFY', 
           'WIT', 'NU', 'CSX', 'UBER', 'GRAB', 'NEE', 'SO', 'PCG', 'MCD']

# %%
portfolio = ["AAPL", "KO", "MCD", "PFE", "MSFT", "TSM", "TSLA", "MRK", "PM", "JNJ" ]

for e in portfolio:
    assert e in universe, f"{e} is not in the universe"

# %%
sentiment_all = {}

for e in universe:

  try: 

    _tmp = [] 
    for headline in Quote(e).outer_news_df["Headline"]:

      sent = TextBlob(headline).sentiment.polarity # -1 to 1 sentiment
      if sent != 0:
        _tmp.append(sent)
    
    sentiment_all[e] = np.average(_tmp)
    # print("Ticker: {}; Avg Sentiment: {}".format(e, sentiment_all[e]))

  except Exception as err:
    print("Error: {} at ticker {}".format(err, e))


  print("Progress: {}/{}".format(universe.index(e)+1, len(universe)), end='\r')
# Out:
# Error: 'Quote' object has no attribute 'outer_news_df' at ticker ABB
# Progress: 111/111

# %%
df_sentiment = pd.DataFrame.from_dict(sentiment_all, orient='index', columns=['Avg. Sentiment'])
df_sentiment.sort_values('Avg. Sentiment', ascending=False).style.background_gradient()
# Out:
# <style type="text/css">
# #T_0f7e6_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0f7e6_row1_col0 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_0f7e6_row2_col0 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_0f7e6_row3_col0 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_0f7e6_row4_col0 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_0f7e6_row5_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_0f7e6_row6_col0 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_0f7e6_row7_col0 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_0f7e6_row8_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_0f7e6_row9_col0 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T
</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f7e6_level0_row0" class="row_heading level0 row0" >NOK</th>
#       <td id="T_0f7e6_row0_col0" class="data row0 col0" >0.556382</td>
#     </tr>
#     <tr>
#       <th id="T_0f7e6_level0_row1" class="row_heading level0 row1" >SHEL</th>
#       <td id="T_0f7e6_row1_col0" class="data row1 col0" >0.516758</td>
#     </tr>
#     <tr>
#       <th id="T_0f7e6_level0_row2" class="row_heading level0 row2" >ABEV</th>
#       <td id="T_0f7e6_row2_col0" class="data row2 col0" >0.426870</td>
#     </tr>
#     <tr>
#       <th id="T_0f7e6_level0_row3" class="row_heading level0 row3" >PG</th>
#       <td id="T_0f7e6_row3_col0" class="data row3 col0" >0.416806</td>
#     </tr>
#     <tr>
#       <th id="T_0f7e6_level0_row4" class="row_heading level0 row4" >NU</th>
#       <td id="T_0f7e6_row4_col0" class="data row4 col0" >0.414193</td>
#     </tr>
#     <tr>
#       <th id="T_0f7e6_level0_row5" class="row_heading level0 row5" >ITUB</th>
#       <td id="T_0f7e6_row5_col0"

# %%
df_sentiment.loc[portfolio].sort_values('Avg. Sentiment', ascending=False).style.background_gradient()
# Out:
# <style type="text/css">
# #T_a29d8_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a29d8_row1_col0 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_a29d8_row2_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_a29d8_row3_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_a29d8_row4_col0 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_a29d8_row5_col0 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_a29d8_row6_col0 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_a29d8_row7_col0 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_a29d8_row8_col0 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_a29d8_row9_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_a29d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a29d8_level0_col0" class="col_heading level0 col0" >Avg. Sentiment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a29d8_level0_row0" class="row_heading level0 row0" >PM</th>
#       <td id="T_a29d8_row0_col0" class="data row0 col0" >0.391060</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row1" class="row_heading level0 row1" >JNJ</th>
#       <td id="T_a29d8_row1_col0" class="data row1 col0" >0.373950</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row2" class="row_heading level0 row2" >MRK</th>
#       <td id="T_a29d8_row2_col0" class="data row2 col0" >0.340928</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row3" class="row_heading level0 row3" >KO</th>
#       <td id="T_a29d8_row3_col0" class="data row3 col0" >0.338643</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row4" class="row_heading level0 row4" >MCD</th>
#       <td id="T_a29d8_row4_col0" class="data row4 col0" >0.288698</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row5" class="row_heading level0 row5" >PFE</th>
#       <td id="T_a29d8_row5_col0" class="data row5 col0" >0.261939</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row6" class="row_heading level0 row6" >TSM</th>
#       <td id="T_a29d8_row6_col0" class="data row6 col0" >0.256066</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row7" class="row_heading level0 row7" >AAPL</th>
#       <td id="T_a29d8_row7_col0" class="data row7 col0" >0.250538</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row8" class="row_heading level0 row8" >MSFT</th>
#       <td id="T_a29d8_row8_col0" class="data row8 col0" >0.168897</td>
#     </tr>
#     <tr>
#       <th id="T_a29d8_level0_row9" class="row_heading level0 row9" >TSLA</th>
#       <td id="T_a29d8_row9_col0" class="data row9 col0" >0.114737</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Get 1 year daily data for each ticker
data = yf.download(universe, start="2020-01-01", end="2021-01-01")['Adj Close']
data = data.dropna(axis=1)
data
# Out:
# [*********************100%***********************]  111 of 111 completed
# ERROR
# 4 Failed downloads:
# ERROR ['ABB']: Exception('ABB: No timezone found, symbol may be delisted')
# ERROR ['NU']: Exception("NU: Data doesn't exist for startDate = 1577854800, endDate = 1609477200")
# ERROR ['CPNG']: Exception("CPNG: Data doesn't exist for startDate = 1577854800, endDate = 1609477200")
# ERROR ['HLN']: Exception("HLN: Data doesn't exist for startDate = 1577854800, endDate = 1609477200")
#                   AAPL       ABBV      ABEV         ABT       AMCR        AMD  \
# Date
# 2020-01-02   73.249031  75.656311  4.183811   81.730209   9.064963  49.099998
# 2020-01-03   72.536888  74.938187  4.130740   80.733826   8.945575  48.599998
# 2020-01-06   73.114883  75.529602  4.086514   81.156822   8.885881  48.389999
# 2020-01-07   72.771019  75.098709  4.095359   80.705635   8.809132  48.250000
# 2020-01-08   73.941635  75.630966  4.104204   81.034622   8.843241  47.830002
# ...                ...        ...       ...         ...        ...        ...
# 2020-12-24  129.850571  92.068710  2.768984  103.451172  10.368696  91.809998
# 2020-12-28  134.494781  92.238121  2.750827  102.916489  10.324158  91.599998
# 2020-12-29  132.703995  93.352646  2.832535  103.432060  10.333065  90.620003
# 2020-12-30  131.572479  93.860870  2.768984  103.537102  10.457774  92.290001
# 2020-12-31  130.559021  95.537117  2.778063  104.539612  10.484497  91.709999
#
#                   AMX        AMZN        AZN        BABA  ...           V  \
# Date                                                      ...
# 2020-01-02  14.912305   94.900497  45.610382  219.770004  ...  186.293243
# 2020-01-03  14.893963   93.748497  45.338840  217.000000  ...  184.811661
# 2020-01-06  14.820593   95.143997  45.148762  216.639999  ...  184.411972
# 2020-01-07  14.600484   95.343002  45.320736  217.630005  ...  183.924637
# 2020-01-08  14.545457   94.598503  45.212124  218.000000  ...  187.073059
# ...               ...         ...        ...         ...  ...         ...
# 2020-12-24  13.438074  158.634506  45.170944  222.000000  ...  204.681427
# 2020-12-28  13.503993  164.197998  45.971577  222.360001  ...  208.535797
# 2020-12-29  13.777086  166.100006  46.455688  236.259995  ...  210.242279
# 2020-12-30  13.871256  164.292496  46.716358  238.389999  ...  214.155457
# 2020-12-31  13.692333  162.846497  46.539478  232.729996  ...  214.518341
#
#                  VALE        VIV        VOD         VZ        WBD        WFC  \
# Date
# 2020-01-02   9.837492  11.860083  15.216392  50.476467  32.220001  48.727352
# 2020-01-03   9.720466  11.809793  15.106755  49.939041  32.029999  48.428181
# 2020-01-06   9.610756  11.692448  15.145909  49.831558  31.959999  48.138084
# 2020-01-07   9.676581  11.675685  15.044100  49.277592  32.070000  47.739204
# 2020-01-08   9.669269  11.650543  15.114583  49.368542  32.110001  47.884262
# ...               ...        ...        ...        ...        ...        ...
# 2020-12-24  12.882509   7.376836  13.881310  50.777046  28.570000  28.139160
# 2020-12-28  12.760470   7.351428  13.914540  50.897861  29.450001  28.224030
# 2020-12-29  12.844373   7.334487  13.823160  50.751160  29.690001  28.082581
# 2020-12-30  12.928273   7.512344  13.831468  50.172974  29.809999  28.054289
# 2020-12-31  12.783356   7.495406  13.690246  50.699383  30.090000  28.459784
#
#                  WIT         WMT        XOM
# Date
# 2020-01-02  3.691714  112.085129  58.054886
# 2020-01-03  3.721169  111.095657  57.588154
# 2020-01-06  3.780079  110.869476  58.030338
# 2020-01-07  3.780079  109.842293  57.555405
# 2020-01-08  3.789898  109.465355  56.687450
# ...              ...         ...        ...
# 2020-12-24  5.518682  137.487122  36.783619
# 2020-12-28  5.498973  139.135025  36.907417
# 2020-12-29  5.508828  138.253586  36.491829
# 2020-12-30  5.558102  138.138611  36.783619
# 2020-12-31  5.567957  138.109879  36.447617
#
# [253 rows x 105 columns]

# %%
drift = {} 

for e in data.columns:
    drift[e] = data[e].pct_change().dropna().mean()

df_drift = pd.DataFrame.from_dict(drift, orient='index', columns=['Avg. Drift'])
df_drift["Sentiment"] = [df_sentiment.loc[e]["Avg. Sentiment"] for e in df_drift.index]
df_drift.sort_values('Avg. Drift', ascending=False).style.background_gradient()
# Out:
# <style type="text/css">
# #T_f9f90_row0_col0, #T_f9f90_row56_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f9f90_row0_col1, #T_f9f90_row7_col0 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_f9f90_row1_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_f9f90_row1_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_f9f90_row2_col0, #T_f9f90_row80_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_f9f90_row2_col1 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_f9f90_row3_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_f9f90_row3_col1, #T_f9f90_row59_col0, #T_f9f90_row60_col0, #T_f9f90_row61_col0 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_f9f90_row4_col0, #T_f9f90_row5_col0, #T_f9f90_row9_col1, #T_f9f90_row35_col1, #T_f9f90_row103_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_f9f90_row4_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_f9f90_row5_col1, #T_f9f90_row9_col0, #T_f9f90_row13_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_f9f90_row6_col0 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_f9f90_row6_col1 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_f9f90_row7_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_f9f90_row8_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_f9f90_row8_col1 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_f9f90_row10_col0, #T_f9f90_row10_col1, #T_f9f90_row59_col1 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_f9f90_row11_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_f9f90_row11_col1, #T_f9f90_row88_col1 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_f9f90_row12_col0, #T_f9f90_row13_col0 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_f9f90_row12_col1, #T_f9f90_row15_col1, #T_f9f90_row32_col0, #T_f9f90_row33_col0, #T_f9f90_row34_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_f9f90_row14_col0, #T_f9f90_row38_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_f9f90_row14_col1, #T_f9f90_row41_col0, #T_f9f90_row42_col0, #T_f9f90_row79_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_f9f90_row15_col0, #T_f9f90_row16_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_f9f90_row16_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_f9f90_row17_col0 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_f9f90_row17_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_f9f90_row18_col0, #T_f9f90_row19_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T